# %% [markdown]
# Gio Fiore 10/11 API Data Report

# %% [markdown]
# I think that Playboi Carti’s 2020 album Whole Lotta Red (WLR) has more danceability and energy than his 2018 album Die Lit (DL) and this will lead to the tracks having more popularity.

# %% [markdown]
# I’m going to collect the track features endpoint but focus on the popularity, danceability, and energy then find the average of these to test my hypothesis. This data is reliable because it is coming directly from Spotify, but the popularity score is unreliable because it updates in real time and may not be an accurate representation of the all time popularity of the songs. The limitation I have come across is that WLR has 24 songs and DL has 19 songs, to make sure I can still test my hypothesis accurately and fairly I will take the first 10 songs of each album and compare them like that.

# %%
import pandas as pd 
import json
import urllib
import requests
import base64

# %%
def get_session_token(SessionID, SessionKey):
    url = 'https://accounts.spotify.com/api/token'
    data = {'grant_type':'client_credentials'}
    encoded_key = base64.b64encode(str(SessionID + ":" + SessionKey).\
                                   encode("ascii")) 
    header = {'Authorization': 'Basic {}'.format(encoded_key.decode("ascii"))}
    response = requests.post(url,
                           data = data,
                           headers = header)
    print(response.status_code)
    return response.json()['access_token']

# %% [markdown]
# Setup to get sessionID and sessionKey for Spotify Dev tools

# %%
keys = pd.read_csv("keys.txt")
#keys

# %% [markdown]
# Adding keys to notebook

# %%
access_token = get_session_token(keys['Client_ID'].iloc[0], keys['Client_Secret'].iloc[0])
#access_token
# Out:
# 200

# %% [markdown]
# Making sure session tokens are 200

# %%
t_features_ep = 'https://api.spotify.com/v1/audio-features'
tracks_ep = 'https://api.spotify.com/v1/tracks'
ab_tracks_ep = 'https://api.spotify.com/v1/albums/{}/tracks'

# %% [markdown]
# Setting up endpoints

# %%
def api_call(endpoint_url, api_header):
    response = requests.get(endpoint_url, headers = api_header)
    print(response.status_code)
    return response.json()

# %% [markdown]
# Setting up api call for showing tracks and track features

# %%
session_header = {'Authorization': 'Bearer {}'.format(access_token)}

# %% [markdown]
# Setting up session header for track features

# %%
wlr_album_id = '2QRedhP5RmKJiJ1i8VgDGR'
dl_album_id = '7dAm8ShwJLFm9SaJ6Yc58O'

# %% [markdown]
# Album IDs for WLR and DL

# %%
ab_tracks_ep.format(wlr_album_id)
# Out:
# 'https://api.spotify.com/v1/albums/2QRedhP5RmKJiJ1i8VgDGR/tracks'

# %%
ab_tracks_ep.format(dl_album_id)
# Out:
# 'https://api.spotify.com/v1/albums/7dAm8ShwJLFm9SaJ6Yc58O/tracks'

# %%
wlr_album_response = api_call(ab_tracks_ep.format(wlr_album_id), session_header)
#wlr_album_response
# Out:
# 200

# %%
dl_album_response = api_call(ab_tracks_ep.format(dl_album_id), session_header)
#dl_album_response
# Out:
# 200

# %% [markdown]
# Making sure WLR & DL album ids are correct

# %%
wlr_album_df = pd.DataFrame(wlr_album_response['items'])
#wlr_album_df

# %%
dl_album_df = pd.DataFrame(dl_album_response['items'])
#dl_album_df

# %% [markdown]
# Setting up data frames for WLR & DL

# %%
wlr_track_ids = ','.join(wlr_album_df['id'].to_list())
#wlr_track_ids

# %%
dl_track_ids = ','.join(dl_album_df['id'].to_list())
#dl_track_ids

# %% [markdown]
# Adding all album track ids to one piece of code to use track features easier.

# %%
wlr_track_features = api_call(t_features_ep + '?ids={}'.format(wlr_track_ids),
                             session_header)
dl_track_features = api_call(t_features_ep + '?ids={}'.format(dl_track_ids),
                             session_header)
# Out:
# 200
# 200

# %% [markdown]
# Setting up track features for both albums

# %%
wlr_track_info = api_call(tracks_ep + '?market=US&ids={}'.format(wlr_track_ids),
                             session_header)
dl_track_info = api_call(tracks_ep + '?market=US&ids={}'.format(dl_track_ids),
                             session_header)
# Out:
# 200
# 200

# %% [markdown]
# Setting up track info for both albums

# %%
wlr_features_df = pd.DataFrame(wlr_track_features['audio_features'])
#wlr_features_df

# %%
dl_features_df = pd.DataFrame(dl_track_features['audio_features'])
#dl_features_df

# %% [markdown]
# Dataframes for both albums track features

# %%
wlr_tracks_df = pd.DataFrame(wlr_track_info['tracks'])
#wlr_tracks_df

# %%
dl_tracks_df = pd.DataFrame(dl_track_info['tracks'])
#dl_tracks_df

# %% [markdown]
# Dataframe for both albums tracks to set up a merge of both to compare data

# %%
wlr_merged = pd.merge(wlr_features_df, wlr_tracks_df,
         how = 'inner', on = 'id')
wlr_merged.head(10)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.773   0.612    8    -5.730     1       0.2320       0.03980
# 1         0.693   0.434    4    -8.786     0       0.3850       0.20400
# 2         0.856   0.570    9    -4.486     1       0.2860       0.00637
# 3         0.923   0.562    1    -7.357     1       0.3040       0.02130
# 4         0.870   0.461    1    -5.786     1       0.2010       0.00456
# 5         0.657   0.604    0    -6.045     1       0.0374       0.02130
# 6         0.885   0.661    4    -5.062     0       0.1410       0.16500
# 7         0.719   0.852    0    -5.232     1       0.1490       0.02400
# 8         0.819   0.638   10    -4.831     0       0.2260       0.03100
# 9         0.437   0.671    1    -4.985     1       0.1220       0.00124
#
#    instrumentalness  liveness  valence  ...              external_ids  \
# 0          0.000000    0.1420   0.3810  ...  {'isrc': 'USUM72024683'}
# 1          0.000000    0.2770   0.5420  ...  {'isrc': 'USUM72024690'}
# 2          0.000000    0.0984   0.1550  ...  {'isrc': 'USUM72024691'}
# 3          0.000000    0.0726   0.4990  ...  {'isrc': 'USUM72024692'}
# 4          0.000000    0.1100   0.4850  ...  {'isrc': 'USUM72024685'}
# 5          0.000000    0.1560   0.1220  ...  {'isrc': 'USUM72024684'}
# 6          0.000000    0.3340   0.4360  ...  {'isrc': 'USUM72024693'}
# 7          0.000000    0.1230   0.4320  ...  {'isrc': 'USUM72024705'}
# 8          0.000116    0.1520   0.1670  ...  {'isrc': 'USUM72024686'}
# 9          0.000010    0.1360   0.0936  ...  {'isrc': 'USUM72024687'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/3c...
# 1  {'spotify': 'https://open.spotify.com/track/0F...
# 2  {'spotify': 'https://open.spotify.com/track/2l...
# 3  {'spotify': 'https://open.spotify.com/track/4C...
# 4  {'spotify': 'https://open.spotify.com/track/0c...
# 5  {'spotify': 'https://open.spotify.com/track/7z...
# 6  {'spotify': 'https://open.spotify.com/track/1e...
# 7  {'spotify': 'https://open.spotify.com/track/6i...
# 8  {'spotify': 'https://open.spotify.com/track/4t...
# 9  {'spotify': 'https://open.spotify.com/track/5u...
#
#                                                 href is_local is_playable  \
# 0  https://api.spotify.com/v1/tracks/3cWmqvMwVQKD...    False        True
# 1  https://api.spotify.com/v1/tracks/0F13K9dwYH2z...    False        True
# 2  https://api.spotify.com/v1/tracks/2lLG56qpLP3U...    False        True
# 3  https://api.spotify.com/v1/tracks/4CYTQpr2jc4u...    False        True
# 4  https://api.spotify.com/v1/tracks/0cgD36xPIJBd...    False        True
# 5  https://api.spotify.com/v1/tracks/7zLMYtNJcabv...    False        True
# 6  https://api.spotify.com/v1/tracks/1eMNW1HQjF1d...    False        True
# 7  https://api.spotify.com/v1/tracks/6i6whmV36EJm...    False        True
# 8  https://api.spotify.com/v1/tracks/4txKMpsSfZRV...    False        True
# 9  https://api.spotify.com/v1/tracks/5uYqmEN6TAAE...    False        True
#
#                              name  popularity  track_number type_y  \
# 0                   Rockstar Made          68             1  track
# 1    Go2DaMoon (feat. Kanye West)          65             2  track
# 2                  Stop Breathing          70             3  track
# 3                           Beno!          61             4  track
# 4                 JumpOutTheHouse          61             5  track
# 5  M3tamorphosis (feat. Kid Cudi)          61             6  track
# 6                          Slay3r          60             7  track
# 7                        No Sl33p          58             8  track
# 8                        New Tank          72             9  track
# 9           Teen X (feat. Future)          59            10  track
#
#                                   uri_y
# 0  spotify:track:3cWmqvMwVQKDigWLSZ3w9h
# 1  spotify:track:0F13K9dwYH2zpTWiR8d628
# 2  spotify:track:2lLG56qpLP3UbcLuzMvkWX
# 3  spotify:track:4CYTQpr2jc4uBScYvpEK2w
# 4  spotify:track:0cgD36xPIJBdKUNJRHYDgP
# 5  spotify:track:7zLMYtNJcabv4h4wBnjNQI
# 6  spotify:track:1eMNW1HQjF1dbb4GtnmpaX
# 7  spotify:track:6i6whmV36EJmxs5zFahMrb
# 8  spotify:track:4txKMpsSfZRV6durPuHVq0
# 9  spotify:track:5uYqmEN6TAAE8ss8YmprNV
#
# [10 rows x 33 columns]

# %%
dl_merged = pd.merge(dl_features_df, dl_tracks_df,
         how = 'inner', on = 'id')
dl_merged.head(10)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.472   0.861    4    -3.966     0       0.0447        0.2830
# 1         0.725   0.725    8    -6.067     0       0.1590        0.0119
# 2         0.754   0.775    7    -5.077     1       0.0660        0.0302
# 3         0.716   0.619    2   -10.227     1       0.3390        0.0271
# 4         0.724   0.450    4    -5.763     0       0.0497        0.0315
# 5         0.673   0.649    1    -8.433     0       0.1960        0.1880
# 6         0.687   0.602    6    -5.005     0       0.0660        0.1380
# 7         0.894   0.590    9    -5.716     1       0.2210        0.0969
# 8         0.722   0.686    7    -6.173     0       0.2400        0.3160
# 9         0.657   0.668    2    -6.208     1       0.1360        0.0273
#
#    instrumentalness  liveness  valence  ...              external_ids  \
# 0          0.000000     0.830    0.358  ...  {'isrc': 'USUM71804186'}
# 1          0.000000     0.086    0.515  ...  {'isrc': 'USUM71804150'}
# 2          0.000000     0.362    0.159  ...  {'isrc': 'USUM71804151'}
# 3          0.000000     0.342    0.584  ...  {'isrc': 'USUM71804169'}
# 4          0.000014     0.111    0.464  ...  {'isrc': 'USUM71804153'}
# 5          0.000000     0.122    0.470  ...  {'isrc': 'USUM71804149'}
# 6          0.000000     0.203    0.309  ...  {'isrc': 'USUM71804157'}
# 7          0.000009     0.329    0.576  ...  {'isrc': 'USUM71804173'}
# 8          0.000000     0.352    0.435  ...  {'isrc': 'USUM71804155'}
# 9          0.000000     0.320    0.227  ...  {'isrc': 'USUM71804159'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/4I...
# 1  {'spotify': 'https://open.spotify.com/track/3L...
# 2  {'spotify': 'https://open.spotify.com/track/1J...
# 3  {'spotify': 'https://open.spotify.com/track/0s...
# 4  {'spotify': 'https://open.spotify.com/track/3K...
# 5  {'spotify': 'https://open.spotify.com/track/2B...
# 6  {'spotify': 'https://open.spotify.com/track/47...
# 7  {'spotify': 'https://open.spotify.com/track/2r...
# 8  {'spotify': 'https://open.spotify.com/track/5w...
# 9  {'spotify': 'https://open.spotify.com/track/1s...
#
#                                                 href is_local is_playable  \
# 0  https://api.spotify.com/v1/tracks/4IO2X2YoXoUM...    False        True
# 1  https://api.spotify.com/v1/tracks/3L0IKstjUgDF...    False        True
# 2  https://api.spotify.com/v1/tracks/1JgkiUg9mSXS...    False        True
# 3  https://api.spotify.com/v1/tracks/0syXbGoFZbTM...    False        True
# 4  https://api.spotify.com/v1/tracks/3K6U7TamNyVS...    False        True
# 5  https://api.spotify.com/v1/tracks/2BJSMvOGABRx...    False        True
# 6  https://api.spotify.com/v1/tracks/475jSz0H6U3d...    False        True
# 7  https://api.spotify.com/v1/tracks/2rPSFKzGeqUW...    False        True
# 8  https://api.spotify.com/v1/tracks/5wPyd3IQAZft...    False        True
# 9  https://api.spotify.com/v1/tracks/1s9DTymg5UQr...    False        True
#
#                                 name  popularity  track_number type_y  \
# 0                  Long Time - Intro          72             1  track
# 1                             R.I.P.          74             2  track
# 2         Lean 4 Real (feat. Skepta)          67             3  track
# 3                          Old Money          60             4  track
# 4    Love Hurts (feat. Travis Scott)          65             5  track
# 5        Shoota (feat. Lil Uzi Vert)          74             6  track
# 6   Right Now (feat. Pi'erre Bourne)          62             7  track
# 7     Poke It Out (with Nicki Minaj)          59             8  track
# 8                         Home (KOD)          63             9  track
# 9  Fell In Luv (feat. Bryson Tiller)          73            10  track
#
#                                   uri_y
# 0  spotify:track:4IO2X2YoXoUMv0M2rwomLC
# 1  spotify:track:3L0IKstjUgDFVQAbQIRZRv
# 2  spotify:track:1JgkiUg9mSXSwcb5Gbi4Ur
# 3  spotify:track:0syXbGoFZbTMXm8hGCEvW0
# 4  spotify:track:3K6U7TamNyVSWcFH8pCQHX
# 5  spotify:track:2BJSMvOGABRxokHKB0OI8i
# 6  spotify:track:475jSz0H6U3duJyNiDS0tT
# 7  spotify:track:2rPSFKzGeqUWwfcCFVkkq3
# 8  spotify:track:5wPyd3IQAZft1vmxoIqGrU
# 9  spotify:track:1s9DTymg5UQrdorZf43JQm
#
# [10 rows x 33 columns]

# %% [markdown]
# The average energy of WLR is 0.607 while the average energy of DL is 0.663. Die Lit has a higher average energy across the first 10 songs.
#
# The average danceability of WLR is 0.763 while the average danceability of DL is 0.702. Whole Lotta Red has a higher average danceability across the first 10 songs.
#
# The average popularity of WLR is 63.5 while the average popularity of DL is 66.9. Die lit has a higher average popularity across the first 10 songs.
#
# Based on this my hypothesis is incorrect because based on the first 10 songs from each album WLR only has a higher average danceability score while DL has a higher average energy and has a higher popularity average.
#
# Another way I can test my hypopthesis is instead take the top 5 songs with the highest popularity scores and see if this makes any difference.

# %%
wlr_top5 = wlr_merged.sort_values(by=['popularity'], ascending=False).head(5)
wlr_top5
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 18         0.785   0.903    2    -4.184     1       0.2100       0.25800
# 11         0.642   0.690   11    -5.101     1       0.2610       0.00599
# 8          0.819   0.638   10    -4.831     0       0.2260       0.03100
# 2          0.856   0.570    9    -4.486     1       0.2860       0.00637
# 19         0.622   0.946    7    -3.593     0       0.0534       0.04400
#
#     instrumentalness  liveness  valence  ...              external_ids  \
# 18          0.000000    0.1690    0.565  ...  {'isrc': 'USUM72024699'}
# 11          0.000001    0.3220    0.641  ...  {'isrc': 'USUM72024688'}
# 8           0.000116    0.1520    0.167  ...  {'isrc': 'USUM72024686'}
# 2           0.000000    0.0984    0.155  ...  {'isrc': 'USUM72024691'}
# 19          0.000000    0.0838    0.336  ...  {'isrc': 'USUM72024700'}
#
#                                         external_urls  \
# 18  {'spotify': 'https://open.spotify.com/track/29...
# 11  {'spotify': 'https://open.spotify.com/track/4C...
# 8   {'spotify': 'https://open.spotify.com/track/4t...
# 2   {'spotify': 'https://open.spotify.com/track/2l...
# 19  {'spotify': 'https://open.spotify.com/track/08...
#
#                                                  href is_local is_playable  \
# 18  https://api.spotify.com/v1/tracks/29TPjc8wxfz4...    False        True
# 11  https://api.spotify.com/v1/tracks/4CzhtKifG867...    False        True
# 8   https://api.spotify.com/v1/tracks/4txKMpsSfZRV...    False        True
# 2   https://api.spotify.com/v1/tracks/2lLG56qpLP3U...    False        True
# 19  https://api.spotify.com/v1/tracks/08dz3ygXyFur...    False        True
#
#               name  popularity  track_number type_y  \
# 18             Sky          79            19  track
# 11     Vamp Anthem          73            12  track
# 8         New Tank          72             9  track
# 2   Stop Breathing          70             3  track
# 19            Over          69            20  track
#
#                                    uri_y
# 18  spotify:track:29TPjc8wxfz4XMn21O7VsZ
# 11  spotify:track:4CzhtKifG867Lu5DNQVBSA
# 8   spotify:track:4txKMpsSfZRV6durPuHVq0
# 2   spotify:track:2lLG56qpLP3UbcLuzMvkWX
# 19  spotify:track:08dz3ygXyFur6bL7Au8u8J
#
# [5 rows x 33 columns]

# %% [markdown]
# The 5 most popular songs from WLR are Sky, Vamp Anthem, New Tank, Stop Breathing, and Over. With an average of 72.6.
#
# These songs have an average energy of 0.749.
#
# These songs have an average danceability of 0.745.

# %%
dl_top5 = dl_merged.sort_values(by=['popularity'], ascending=False).head(5)
dl_top5
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 5          0.673   0.649    1    -8.433     0       0.1960        0.1880
# 1          0.725   0.725    8    -6.067     0       0.1590        0.0119
# 9          0.657   0.668    2    -6.208     1       0.1360        0.0273
# 0          0.472   0.861    4    -3.966     0       0.0447        0.2830
# 10         0.762   0.705    6    -5.195     0       0.1640        0.0906
#
#     instrumentalness  liveness  valence  ...              external_ids  \
# 5                0.0     0.122    0.470  ...  {'isrc': 'USUM71804149'}
# 1                0.0     0.086    0.515  ...  {'isrc': 'USUM71804150'}
# 9                0.0     0.320    0.227  ...  {'isrc': 'USUM71804159'}
# 0                0.0     0.830    0.358  ...  {'isrc': 'USUM71804186'}
# 10               0.0     0.170    0.264  ...  {'isrc': 'USUM71804152'}
#
#                                         external_urls  \
# 5   {'spotify': 'https://open.spotify.com/track/2B...
# 1   {'spotify': 'https://open.spotify.com/track/3L...
# 9   {'spotify': 'https://open.spotify.com/track/1s...
# 0   {'spotify': 'https://open.spotify.com/track/4I...
# 10  {'spotify': 'https://open.spotify.com/track/50...
#
#                                                  href is_local is_playable  \
# 5   https://api.spotify.com/v1/tracks/2BJSMvOGABRx...    False        True
# 1   https://api.spotify.com/v1/tracks/3L0IKstjUgDF...    False        True
# 9   https://api.spotify.com/v1/tracks/1s9DTymg5UQr...    False        True
# 0   https://api.spotify.com/v1/tracks/4IO2X2YoXoUM...    False        True
# 10  https://api.spotify.com/v1/tracks/500l6Cwe40hk...    False        True
#
#                                  name  popularity  track_number type_y  \
# 5         Shoota (feat. Lil Uzi Vert)          74             6  track
# 1                              R.I.P.          74             2  track
# 9   Fell In Luv (feat. Bryson Tiller)          73            10  track
# 0                   Long Time - Intro          72             1  track
# 10                            Foreign          71            11  track
#
#                                    uri_y
# 5   spotify:track:2BJSMvOGABRxokHKB0OI8i
# 1   spotify:track:3L0IKstjUgDFVQAbQIRZRv
# 9   spotify:track:1s9DTymg5UQrdorZf43JQm
# 0   spotify:track:4IO2X2YoXoUMv0M2rwomLC
# 10  spotify:track:500l6Cwe40hkPqS7Sf7ufY
#
# [5 rows x 33 columns]

# %% [markdown]
# The 5 most popular songs from DL are Shoota, R.I.P., Fell in Luv, Long Time, and Foreign. With an average of 72.8.
#
# These songs have an average energy of 0.722.
#
# These songs have an average danceability of 0.658.

# %% [markdown]
# Taking the 5 most popular songs from each album shows that DL has a slightly higher average popularity score but WLR has a higher average energy and danceability.

# %% [markdown]
# In conclusion, based on the data collected from the first 10 songs of each album and the 5 most popular songs my hypothesis was incorrect because in both situations the energy and danceability of the songs had no effect on the popularity.
#
# Since popularity is an unreliable metric in this case, another way to test this hypothesis would be to manually get the number of streams from each album and see if this has any difference.
